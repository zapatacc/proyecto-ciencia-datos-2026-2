# %% [markdown]
# # Clase N — Título
#
# **Módulo:** nombre
#
# **Intención:** una frase en lenguaje no técnico.

# %% [markdown]
# ## Punto de partida
#
# **Prerrequisitos concretos:**
#
# **Resultado observable:**

# %% [markdown]
# ## Agenda — 100 minutos
#
# | Tiempo | Actividad |
# |---:|---|
# | 10 min | Recuperación y objetivo |
# | 20 min | Conceptos y demostración |
# | 55 min | Práctica guiada o reto |
# | 10 min | Verificación por parejas |
# | 5 min | Evidencia de salida |

# %% [markdown]
# ## Conceptos mínimos
#
# Incluye sólo lo necesario para realizar la práctica.

# %% [markdown]
# ## Demostración docente
#
# Describe el cambio observable y su conexión con el caso conductor.

# %% [markdown]
# ## Práctica guiada
#
# Incluye checkpoints y rutas exactas.

# %% [markdown]
# ## Reto corto
#
# Una adaptación pequeña que requiera decidir, no copiar.

# %% [markdown]
# ## Errores frecuentes
#
# - Síntoma, causa probable y siguiente verificación.

# %% [markdown]
# ## Evidencia de salida
#
# Archivo, comando, captura, PR o explicación verificable.

# %% [markdown]
# ## Preparación para la siguiente clase
#
# Acciones concretas y referencias oficiales.
